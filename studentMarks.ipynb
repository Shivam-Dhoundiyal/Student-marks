# %%
import pandas as pd
from sklearn import linear_model
x = {'d1' : [2.5,5.1,3.2,8.5,3.5,1.5,9.2,5.5,8.3,2.7,7.7,5.9,4.5,3.3,1.1,8.9,2.5,1.9,6.1,7.4,2.7,4.8,3.8,6.9,7.8], 'd2' : [21,47,27,75,30,20,88,60,81,25,85,62,41,42,17,95,30,24,67,69,30,54,35,76,6]}
data = pd.DataFrame(data = x)
data
# Out:
#      d1  d2
# 0   2.5  21
# 1   5.1  47
# 2   3.2  27
# 3   8.5  75
# 4   3.5  30
# 5   1.5  20
# 6   9.2  88
# 7   5.5  60
# 8   8.3  81
# 9   2.7  25
# 10  7.7  85
# 11  5.9  62
# 12  4.5  41
# 13  3.3  42
# 14  1.1  17
# 15  8.9  95
# 16  2.5  30
# 17  1.9  24
# 18  6.1  67
# 19  7.4  69
# 20  2.7  30
# 21  4.8  54
# 22  3.8  35
# 23  6.9  76
# 24  7.8   6

# %%
reg = linear_model.LinearRegression()
reg.fit(data[['d1']],data['d2'])

print(reg.predict([[9.25]]))
# Out:
# [83.53285838]
